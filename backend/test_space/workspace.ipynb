# %%
single_data = "February_10/0b260629-9386-49d6-a66b-91ccbd3a4abc_3002eeae-28b4-40ca-8089-2ce1ec603642.nakama-0"
data_path = '/home/eaglex/eagleSpace/GAME_DEV/eagle_game_analytics/backend/data/player_data'

# %%
import pandas as pd

# df = pd.read_parquet(data_path + single_data, engine="pyarrow")
df = pd.read_parquet(data_path+ "February_10/", engine="pyarrow")

# %%
df

# %%
df.columns

# %%
df['event'].unique()

# %%
df['map_id'].unique()

# %%
df['match_id'].unique()
